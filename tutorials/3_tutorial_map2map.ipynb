# %%
# %load_ext autoreload
# %autoreload 2

# %%
import yaml
import pickle

from cryo_challenge.config_validation import (
    MapToMapInputConfig,
    MapToMapResultsValidator,
)

# %% [markdown]
# After you preprocess your data (submission_*.pt), you can compute a map to map distance matrix, for various distance functions, by the following steps.

# %% [markdown]
# # 1. Create a config file
# The config file (e.g. `config_files/config_map_to_map_distance_matrix.yaml`) has information about how to read the preprocessed submission and ground truth data, and how to perform the map to map distance analysis.

# %% [markdown]
# Here is an example of the config file

# %%
config_m2m_path = "../config_files/config_map_to_map.yaml"
with open(config_m2m_path, "r") as file:
    config = yaml.safe_load(file)

config = MapToMapInputConfig(**config)
print(config.model_dump_json(indent=2))
config = config.model_dump()
# Out:
# {
#   "data_params": {
#     "box_size": 224,
#     "voxel_size": 2.146,
#     "submission_params": {
#       "path_to_submission_file": "../data/dataset_2_ground_truth/submission_averaged_gt.pt",
#       "volume_key": "volumes",
#       "metadata_key": "populations",
#       "label_key": "id"
#     },
#     "ground_truth_params": {
#       "path_to_volumes": "../data/dataset_2_ground_truth/maps_gt_flat.pt",
#       "path_to_metadata": "../data/dataset_2_ground_truth/metadata.csv"
#     },
#     "mask_params": {
#       "apply_mask": true,
#       "path_to_mask": "../data/dataset_2_ground_truth/mask_dilated_wide_224x224.mrc"
#     }
#   },
#   "metrics": {
#     "l2": {
#       "chunk_size_submission": 20,
#       "chunk_size_gt": 100,
#       "normalize_params": null,
#       "low_memory": null,
#       "compute_self_metric": true
#     },
#     "corr": {
#       "chunk_size_submission": 20,
#       "chunk_size_gt": 100,
#       "normalize_params": null,
#       "low_memory": null,
# ...

# %% [markdown]
# These docstrings in `MapToMapInputConfig` explain more about the config file entries

# %% [markdown]
# # 2. Run `run_map_to_map_pipeline`
#
# `run_map_to_map_pipeline --config config_files/config_map_to_map.yaml`

# %% [markdown]
# The output (of step #1) is validated with `cryo_challenge.config_validation.MapToMapResultsValidator` before writing to disk. Refer to this class for explanation of the fields.

# %%
with open(config["path_to_output_file"], "rb") as f:
    results_dict = pickle.load(f)
_ = MapToMapResultsValidator(**results_dict)
